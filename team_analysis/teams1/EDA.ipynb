# %%
import json
import matplotlib.pyplot as plt

input_file = open ('../team_names/team_names1.json')
json_array = json.load(input_file)
store_list = []
teams1=json_array["names"]

input_file = open ('../team_names/team_names2.json')
json_array = json.load(input_file)
store_list = []
teams2=json_array["names"]

input_file = open ('../team_names/team_names3.json')
json_array = json.load(input_file)
store_list = []
teams3=json_array["names"]


input_file = open ('../team_names/team_names4.json')
json_array = json.load(input_file)
store_list = []
teams4=json_array["names"]

input_file = open ('../team_names/team_names5.json')
json_array = json.load(input_file)
store_list = []
teams5=json_array["names"]

input_file = open ('../team_names/team_names6.json')
json_array = json.load(input_file)
store_list = []
teams6=json_array["names"]

input_file = open ('../team_names/team_names7.json')
json_array = json.load(input_file)
store_list = []
teams7=json_array["names"]

print(set(teams1+teams2+teams3+teams4+teams5+teams6+teams7))


#print(json_array["names"])
"""arr=[]
for i in json_array["names"]:
    string=i;
    final_string= "../teams1/"+string+".csv"
    arr.append(final_string)
data_frames = []
for file_name in arr:
    data = pd.read_csv(file_name)
    data_frames.append(data)
la_liga = pd.concat(data_frames)
data= la_liga[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points',"year"]]

#print(data)"""

"""arr1=[]
for i in teams:
   dat=data[data['team'] == str(i)]
   arr1.append(dat)
#print(arr1)
print(len(arr1))
for  i  in arr1:
    plt.plot(i['year'], i["points"], label=i["team"])

plt.xlabel('Year')
plt.ylabel('Points')
plt.title('La Liga Team Performance over Time')


plt.legend()
# show the plot
plt.show()"""
# Out:
# {'Espanyol', 'Atlético Bilbao', 'Hércules', 'Valencia', 'Alavés', 'Cultural Leonesa', 'Córdoba', 'Real Gijón', 'Getafe', 'Mallorca', 'Celta Vigo', 'Elche', 'Jaén', 'Valladolid', 'Murcia', 'Barcelona', 'Atlético Madrid', 'Burgos', 'Tenerife', 'Racing Santander', 'Real Santander', 'Rayo Vallecano', 'Betis', 'Lérida', 'Real Murcia', 'Salamanca', 'Leganés', 'Extremadura', 'Athletic Bilbao', 'Atlético Tetuán', 'Numancia', 'Mérida', 'Logroñés', 'Sabadell', 'Oviedo', 'Albacete', 'Cádiz', 'Real Burgos', 'Zaragoza', 'Pontevedra', 'Recreativo', 'Huesca', 'Levante', 'Real Sociedad', 'Castellón', 'Málaga', 'Deportivo La Coruña', 'Gimnàstic', 'Las Palmas', 'Villarreal', 'Compostela', 'Xerez', 'Almería', 'Eibar', 'Real Madrid', 'Granada', 'Alcoyano', 'Sporting Gijón', 'Celta de Vigo', 'Condal', 'Real Betis', 'Girona', 'Celta', 'Lleida', 'Sevilla', 'Osasuna', 'Español'}
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
string="Alavés.csv"
data=pd.read_csv(string)
data= data[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points',"year"]]
plt.plot(data['year'], data["points"], label=data["team"])

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
string="Espanyol.csv"
data=pd.read_csv(string)
data= data[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points',"year"]]
plt.plot(data['year'], data["points"], label=data["team"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 import numpy as np
#       4 string="Espanyol.csv"
# ----> 5 data=pd.read_csv(string)
#       6 data= data[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points',"year"]]
#       7 plt.plot(data['year'], data["points"], label=data["team"])
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
