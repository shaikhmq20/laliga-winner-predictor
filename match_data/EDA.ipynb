# %%
import pandas as pd
import numpy as np
arr=[]
year1=1950
year2=1951
while(year1!=1960):
    string=str(year1)+"-"+str(year2)[2:]
    final_string="laliga_points_table_"+string+".csv"
    arr.append(final_string)
    year1=year1+1
    year2=year2+1
data_frames = []
for file_name in arr:
    data = pd.read_csv(file_name)
    data_frames.append(data)
la_liga = pd.concat(data_frames)



     
     
data= la_liga[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points']]
points=data["points"]

# %%
import json
import matplotlib.pyplot as plt

input_file = open ('../team_names/team_names1.json')
json_array = json.load(input_file)
store_list = []
teams=json_array["names"]
#print(json_array["names"])
arr=[]
for i in json_array["names"]:
    string=i;
    final_string= "../teams1/"+string+".csv"
    arr.append(final_string)
data_frames = []
for file_name in arr:
    data = pd.read_csv(file_name)
    data_frames.append(data)
la_liga = pd.concat(data_frames)
data= la_liga[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points',"year"]]

#print(data)

"""arr1=[]
for i in teams:
   dat=data[data['team'] == str(i)]
   arr1.append(dat)
#print(arr1)
print(len(arr1))
for  i  in arr1:
    plt.plot(i['year'], i["points"], label=i["team"])

plt.xlabel('Year')
plt.ylabel('Points')
plt.title('La Liga Team Performance over Time')


plt.legend()
# show the plot
plt.show()"""
# Out:
# 32

# %%
import matplotlib as plt
import pandas as pd
import numpy as np
string="Alavés.csv"
data=pd.read_csv(string)
data= data[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points']]
plt.plot(i['year'], i["points"], label=i["team"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 import numpy as np
#       4 string="Alavés.csv"
# ----> 5 data=pd.read_csv(string)
#       6 data= data[['position', 'team', 'played', 'won', 'drawn', 'lost', 'goals_for', 'goals_against', 'goal_difference', 'points']]
#       7 plt.plot(i['year'], i["points"], label=i["team"])
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...
