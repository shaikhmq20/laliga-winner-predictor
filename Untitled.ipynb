# %%
import pandas as pd

# %%
df = pd.read_csv("normalized_data/normalized.csv")

# %%
df
# Out:
#       position             team  played        won      drawn       lost
# 0            1  Atlético Madrid      30  17.000000   6.000000   7.000000  \
# 1            2          Sevilla      30  17.000000   4.000000   9.000000
# 2            3         Valencia      30  17.000000   3.000000  10.000000
# 3            4        Barcelona      30  16.000000   3.000000  11.000000
# 4            5    Real Sociedad      30  15.000000   5.000000  10.000000
# ...        ...              ...     ...        ...        ...        ...
# 1323        16         Mallorca      30   7.894737   7.105263  15.000000
# 1324        17            Cádiz      30   6.315789  11.842105  11.842105
# 1325        18          Granada      30   6.315789  11.052632  12.631579
# 1326        19          Levante      30   6.315789   8.684211  15.000000
# 1327        20           Alavés      30   6.315789   5.526316  18.157895
#
#       goals_for  goals_against  goal_difference     points     year
# ...
